# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Class/Text Mining/GPT2-Chinese-old_gpt_2_chinese_before_2021_4_22
# Out:
# /content/drive/MyDrive/Class/Text Mining/GPT2-Chinese-old_gpt_2_chinese_before_2021_4_22

# %%
import pandas as pd
data = pd.read_csv("data/AllMalePrizedArtist.csv")
print(data.shape)
print(data.columns)
# Out:
# (4525, 4)
# Index(['artistName', 'trackName', 'lyric_line', 'lyric_full'], dtype='object')

# %%
lyrics = list(data['lyric_full'])
print(len(lyrics))
print(type(lyrics))
# Out:
# 4525
# <class 'list'>

# %%
# to json file
import json 
json_string = json.dumps(lyrics)

with open("./data/all.json", "w") as file:
        file.write(json_string)

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.7/311.7 KB 26.4 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 97.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 MB 17.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 77.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 880.6/880.6 KB 70.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.7/132.7 KB 21.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.6/79.6 KB 15.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 108.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 KB 23.7 MB/s eta 0:00:00
# ...

# %%
# !python train.py --device=0 --epochs=50 --batch_size=5 --min_length=10 --raw_data_path=data/all.json --output_dir=model_all/ --raw
# Out:
# 串流輸出內容已截斷至最後 5000 行。
# now time: 6:3. Step 2 of piece 71 of epoch 29, loss 1.1750526428222656
# now time: 6:3. Step 3 of piece 71 of epoch 29, loss 1.1199363470077515
# now time: 6:3. Step 1 of piece 72 of epoch 29, loss 1.300378680229187
# now time: 6:3. Step 2 of piece 72 of epoch 29, loss 1.142943263053894
# now time: 6:3. Step 1 of piece 73 of epoch 29, loss 2.1929008960723877
# now time: 6:3. Step 1 of piece 74 of epoch 29, loss 2.1662445068359375
# now time: 6:3. Step 1 of piece 75 of epoch 29, loss 1.8177894353866577
# now time: 6:3. Step 1 of piece 76 of epoch 29, loss 1.049018383026123
# now time: 6:3. Step 2 of piece 76 of epoch 29, loss 0.9864607453346252
# now time: 6:3. Step 3 of piece 76 of epoch 29, loss 0.8439918756484985
# now time: 6:3. Step 1 of piece 77 of epoch 29, loss 2.6342926025390625
# now time: 6:3. Step 1 of piece 78 of epoch 29, loss 1.6568362712860107
# now time: 6:3. Step 2 of piece 78 of epoch 29, loss 1.3444525003433228
# ...

# %%
# !python generate.py --length=150 --nsamples=5 --prefix="下雨" --temperature=0.7 --model_path=model_all/model_epoch50/ --save_samples --save_samples_path=output/epoch_all_50
# Out:
# 2023-01-05 07:39:44.919278: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# args:
# Namespace(batch_size=1, device='0,1,2,3', fast_pattern=False, length=150, model_config='config/model_config_small.json', model_path='model_all/model_epoch50/', no_wordpiece=False, nsamples=5, prefix='下雨', repetition_penalty=1.0, save_samples=True, save_samples_path='output/epoch_all_50', segment=False, temperature=0.7, tokenizer_path='cache/vocab_small.txt', topk=8, topp=0)
# 100% 150/150 [00:02<00:00, 74.14it/s]
# ======================================== SAMPLE 1 ========================================
#
# 下雨過的樹，冷漠，走過，萬年的我，四季，也許會有太多的傷口，滿腔牆，我漂亮掛在公路，我在我身邊，一個人往上，我的世界，我還沒有人群陌生人怎樣，我還擁抱我，最後，與人往前走。我被磨的行不願陪我，我還沒有人靜的太多太多人單純白我不愛我不完整個人往上，我，我不想要忘，我好不想回
#
# 我不想，唱一條海，唱歌唱著我
# 100% 150/150 [00:01<00:00, 107.57it/s]
# ...

# %%
# !python generate.py --length=150 --nsamples=5 --prefix="下雨" --temperature=0.7 --model_path=model_all/model_epoch45/ --save_samples --save_samples_path=output/epoch_all_45
# Out:
# 2023-01-05 07:41:52.466043: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# args:
# Namespace(batch_size=1, device='0,1,2,3', fast_pattern=False, length=150, model_config='config/model_config_small.json', model_path='model_all/model_epoch45/', no_wordpiece=False, nsamples=5, prefix='下雨', repetition_penalty=1.0, save_samples=True, save_samples_path='output/epoch_all_45', segment=False, temperature=0.7, tokenizer_path='cache/vocab_small.txt', topk=8, topp=0)
# 100% 150/150 [00:02<00:00, 70.81it/s]
# ======================================== SAMPLE 1 ========================================
#
# 下雨過的美麗，我們，忘記記憶，忘記記不曾經過的回憶，忘記我的回憶，忘記我的回憶。忘記我的走在追逐漸延自己，為何錯，還是忘記多年我們不了我們不了他不了他，總是很難求，親諾，好在心中，還算哭不算，這，這，被人性，微微妙，她在這，親切給太多晚，我們都已經是藉口，太多心，我，我徘徊，一句話，一句話，無法，偶爾想
# 100% 150/150 [00:01<00:00, 108.64it/s]
# ...

# %%
# !python generate.py --length=150 --nsamples=5 --prefix="下雨" --temperature=0.1 --model_path=model_all/model_epoch50/ --save_samples --save_samples_path=output/epoch_all_50_2
# Out:
# 2023-01-05 07:45:59.034898: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# args:
# Namespace(batch_size=1, device='0,1,2,3', fast_pattern=False, length=150, model_config='config/model_config_small.json', model_path='model_all/model_epoch50/', no_wordpiece=False, nsamples=5, prefix='下雨', repetition_penalty=1.0, save_samples=True, save_samples_path='output/epoch_all_50_2', segment=False, temperature=0.1, tokenizer_path='cache/vocab_small.txt', topk=8, topp=0)
# 100% 150/150 [00:02<00:00, 74.83it/s]
# ======================================== SAMPLE 1 ========================================
#
# 下雨過的回憶，又是誰，誰比誰比誰，自私，要測住，要掩蓋，我還有謊言，要我要我怎樣的罪潛意表情緒，要我過問題，才不過份，又狠一念的人的程式，抱歉還來不過問一切，無法，又怎麼辦，在這是人的。我們還有幾番，你的認，才問題，一片段，問題，悲，又如果子，問，痛一場，我們都該，痛苦了，又無法算了，你又如果換季的殘忍
# 100% 150/150 [00:01<00:00, 107.02it/s]
# ...

# %%
# !python generate.py --length=150 --nsamples=5 --prefix="下雨" --temperature=0.9 --model_path=model_all/model_epoch50/ --save_samples --save_samples_path=output/epoch_all_50_3
# Out:
# 2023-01-05 07:47:11.777573: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# args:
# Namespace(batch_size=1, device='0,1,2,3', fast_pattern=False, length=150, model_config='config/model_config_small.json', model_path='model_all/model_epoch50/', no_wordpiece=False, nsamples=5, prefix='下雨', repetition_penalty=1.0, save_samples=True, save_samples_path='output/epoch_all_50_3', segment=False, temperature=0.9, tokenizer_path='cache/vocab_small.txt', topk=8, topp=0)
# 100% 150/150 [00:02<00:00, 57.68it/s]
# ======================================== SAMPLE 1 ========================================
#
# 下雨過的回憶，又再問題。如果關於沒有盡力追尋常常在人群裡，不安穩住要只是我們能量，不必再說一個人群嗜血液之中，能不願失敗，能不能，遙遠，如果是燦爛的夢想要抓住。能，能，寧願意，就算要我會把這裡的靈魂，就像火焰，浪漫，別管前進行走開雙眼前衝撞撞撞，用失戀愛從我的力量，把這一點火藥，用心中的記永遠的靈魂，用
# 100% 150/150 [00:01<00:00, 102.02it/s]
# ...

# %%
# !python generate.py --length=150 --nsamples=5 --prefix="愛情" --temperature=0.5 --model_path=model_all/model_epoch50/ --save_samples --save_samples_path=output/epoch_all_50_4
# Out:
# 2023-01-05 07:49:21.711743: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# args:
# Namespace(batch_size=1, device='0,1,2,3', fast_pattern=False, length=150, model_config='config/model_config_small.json', model_path='model_all/model_epoch50/', no_wordpiece=False, nsamples=5, prefix='愛情', repetition_penalty=1.0, save_samples=True, save_samples_path='output/epoch_all_50_4', segment=False, temperature=0.5, tokenizer_path='cache/vocab_small.txt', topk=8, topp=0)
# 100% 150/150 [00:02<00:00, 74.72it/s]
# ======================================== SAMPLE 1 ========================================
#
# 愛情節
#
# 妳說我的一顆心溫柔的讓人嘆息，從來不會要求什麼總是沒有脾氣，難免會要體驗，我說我別人說不要求什麼都靠近，我的幸福都靠近距離，難免什麼不要妳覺得我怎麼能夠了不要妳說。我怎麼都不要妳是不要妳愛。我的太多苦苦妳是離，我怎麼猜，我無心。不要妳的太多，就算什麼都不願意，我不要妳給我不愛。我的每個理，就為
# 100% 150/150 [00:01<00:00, 105.85it/s]
# ...

# %%
# !python generate.py --length=20 --nsamples=5 --prefix="下雨" --temperature=0.9 --model_path=model_all/model_epoch1/ --save_samples --save_samples_path=output/epoch_all_1
# Out:
# 2023-01-05 12:24:04.253422: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# args:
# Namespace(batch_size=1, device='0,1,2,3', fast_pattern=False, length=20, model_config='config/model_config_small.json', model_path='model_all/model_epoch1/', no_wordpiece=False, nsamples=5, prefix='下雨', repetition_penalty=1.0, save_samples=True, save_samples_path='output/epoch_all_1', segment=False, temperature=0.9, tokenizer_path='cache/vocab_small.txt', topk=8, topp=0)
# 100% 20/20 [00:00<00:00, 20.56it/s]
# ======================================== SAMPLE 1 ========================================
#
# 下雨，。我，不我，我，我，我不。，，，，一不
# 100% 20/20 [00:00<00:00, 103.97it/s]
# ======================================== SAMPLE 2 ========================================
#
# 下雨我我，我的我，不我，我，的。的，我，的我
# 100% 20/20 [00:00<00:00, 37.71it/s]
# ...

# %%
# !python generate.py --length=20 --nsamples=5 --prefix="下雨" --temperature=0.9 --model_path=model_all/model_epoch10/ --save_samples --save_samples_path=output/epoch_all_10
# Out:
# 2023-01-05 12:24:17.181794: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# args:
# Namespace(batch_size=1, device='0,1,2,3', fast_pattern=False, length=20, model_config='config/model_config_small.json', model_path='model_all/model_epoch10/', no_wordpiece=False, nsamples=5, prefix='下雨', repetition_penalty=1.0, save_samples=True, save_samples_path='output/epoch_all_10', segment=False, temperature=0.9, tokenizer_path='cache/vocab_small.txt', topk=8, topp=0)
# 100% 20/20 [00:00<00:00, 23.70it/s]
# ======================================== SAMPLE 1 ========================================
#
# 下雨，我們在我們都是我們的，我們都是我們是，
# 100% 20/20 [00:00<00:00, 106.69it/s]
# ======================================== SAMPLE 2 ========================================
#
# 下雨下的我的我說我說這樣，我的人，我說說我說
# 100% 20/20 [00:00<00:00, 105.11it/s]
# ...

# %%
# !python generate.py --length=20 --nsamples=5 --prefix="下雨" --temperature=0.9 --model_path=model_all/model_epoch20/ --save_samples --save_samples_path=output/epoch_all_20
# Out:
# 2023-01-05 12:24:29.470555: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# args:
# Namespace(batch_size=1, device='0,1,2,3', fast_pattern=False, length=20, model_config='config/model_config_small.json', model_path='model_all/model_epoch20/', no_wordpiece=False, nsamples=5, prefix='下雨', repetition_penalty=1.0, save_samples=True, save_samples_path='output/epoch_all_20', segment=False, temperature=0.9, tokenizer_path='cache/vocab_small.txt', topk=8, topp=0)
# 100% 20/20 [00:00<00:00, 24.79it/s]
# ======================================== SAMPLE 1 ========================================
#
# 下雨，風吹過了，吹過了樹，吹過了河，吹乾了美
# 100% 20/20 [00:00<00:00, 106.17it/s]
# ======================================== SAMPLE 2 ========================================
#
# 下雨，只剩下，我們相遇著，幾句話，我們都沒說
# 100% 20/20 [00:00<00:00, 106.01it/s]
# ...

# %%
# !python generate.py --length=20 --nsamples=5 --prefix="下雨" --temperature=0.9 --model_path=model_all/model_epoch50/ --save_samples --save_samples_path=output/epoch_all_50_few
# Out:
# 2023-01-05 12:25:18.596249: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# args:
# Namespace(batch_size=1, device='0,1,2,3', fast_pattern=False, length=20, model_config='config/model_config_small.json', model_path='model_all/model_epoch50/', no_wordpiece=False, nsamples=5, prefix='下雨', repetition_penalty=1.0, save_samples=True, save_samples_path='output/epoch_all_50_few', segment=False, temperature=0.9, tokenizer_path='cache/vocab_small.txt', topk=8, topp=0)
# 100% 20/20 [00:00<00:00, 22.89it/s]
# ======================================== SAMPLE 1 ========================================
#
# 下雨過的影子，咁有你的表情緒，吹向你目光芒，
# 100% 20/20 [00:00<00:00, 97.97it/s]
# ======================================== SAMPLE 2 ========================================
#
# 下雨過的回憶，如果我有感覺，生命運氣，繼續，
# 100% 20/20 [00:00<00:00, 102.38it/s]
# ...
